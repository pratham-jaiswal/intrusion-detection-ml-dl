# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv("TrafficLabelling/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv")

# %%
print(df1[" Label"].value_counts())
df1.head()
# Out:
# DDoS      128027
# BENIGN     97718
# Name:  Label, dtype: int64
#                                    Flow ID       Source IP   Source Port  \
# 0  192.168.10.5-104.16.207.165-54865-443-6  104.16.207.165           443
# 1    192.168.10.5-104.16.28.216-55054-80-6   104.16.28.216            80
# 2    192.168.10.5-104.16.28.216-55055-80-6   104.16.28.216            80
# 3  192.168.10.16-104.17.241.25-46236-443-6   104.17.241.25           443
# 4  192.168.10.5-104.19.196.102-54863-443-6  104.19.196.102           443
#
#    Destination IP   Destination Port   Protocol      Timestamp  \
# 0    192.168.10.5              54865          6  7/7/2017 3:30
# 1    192.168.10.5              55054          6  7/7/2017 3:30
# 2    192.168.10.5              55055          6  7/7/2017 3:30
# 3   192.168.10.16              46236          6  7/7/2017 3:30
# 4    192.168.10.5              54863          6  7/7/2017 3:30
#
#     Flow Duration   Total Fwd Packets   Total Backward Packets  ...  \
# ...

# %%
df2 = pd.read_csv("TrafficLabelling/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv")

# %%
print(df2[" Label"].value_counts())
df2.head()
# Out:
# PortScan    158930
# BENIGN      127537
# Name:  Label, dtype: int64
#                                   Flow ID      Source IP   Source Port  \
# 0  192.168.10.12-192.168.10.50-35396-22-6  192.168.10.12         35396
# 1  192.168.10.16-192.168.10.50-60058-22-6  192.168.10.16         60058
# 2  192.168.10.12-192.168.10.50-35396-22-6  192.168.10.12         35396
# 3  192.168.10.12-192.168.10.50-35398-22-6  192.168.10.12         35398
# 4  192.168.10.12-192.168.10.50-35396-22-6  192.168.10.50            22
#
#    Destination IP   Destination Port   Protocol      Timestamp  \
# 0   192.168.10.50                 22          6  7/7/2017 1:00
# 1   192.168.10.50                 22          6  7/7/2017 1:00
# 2   192.168.10.50                 22          6  7/7/2017 1:00
# 3   192.168.10.50                 22          6  7/7/2017 1:00
# 4   192.168.10.12              35396          6  7/7/2017 1:00
#
#     Flow Duration   Total Fwd Packets   Total Backward Packets  ...  \
# ...

# %%
df3 = pd.read_csv("TrafficLabelling/Friday-WorkingHours-Morning.pcap_ISCX.csv")

# %%
print(df3[" Label"].value_counts())
df3.head()
# Out:
# BENIGN    189067
# Bot         1966
# Name:  Label, dtype: int64
#                                    Flow ID      Source IP   Source Port  \
# 0  192.168.10.3-192.168.10.50-3268-56108-6  192.168.10.50         56108
# 1   192.168.10.3-192.168.10.50-389-42144-6  192.168.10.50         42144
# 2                    8.0.6.4-8.6.0.1-0-0-0        8.6.0.1             0
# 3   192.168.10.9-224.0.0.252-63210-5355-17   192.168.10.9         63210
# 4            192.168.10.9-224.0.0.22-0-0-0   192.168.10.9             0
#
#    Destination IP   Destination Port   Protocol      Timestamp  \
# 0    192.168.10.3               3268          6  7/7/2017 8:59
# 1    192.168.10.3                389          6  7/7/2017 8:59
# 2         8.0.6.4                  0          0  7/7/2017 9:00
# 3     224.0.0.252               5355         17  7/7/2017 9:00
# 4      224.0.0.22                  0          0  7/7/2017 9:00
#
#     Flow Duration   Total Fwd Packets   Total Backward Packets  ...  \
# ...

# %%
df4 = pd.read_csv("TrafficLabelling/Monday-WorkingHours.pcap_ISCX.csv")

# %%
print(df4[" Label"].value_counts())
df4.head()
# Out:
# BENIGN    529918
# Name:  Label, dtype: int64
#                                   Flow ID      Source IP   Source Port  \
# 0   192.168.10.5-8.254.250.126-49188-80-6  8.254.250.126            80
# 1   192.168.10.5-8.254.250.126-49188-80-6  8.254.250.126            80
# 2   192.168.10.5-8.254.250.126-49188-80-6  8.254.250.126            80
# 3   192.168.10.5-8.254.250.126-49188-80-6  8.254.250.126            80
# 4  192.168.10.14-8.253.185.121-49486-80-6  8.253.185.121            80
#
#    Destination IP   Destination Port   Protocol            Timestamp  \
# 0    192.168.10.5              49188          6  03/07/2017 08:55:58
# 1    192.168.10.5              49188          6  03/07/2017 08:55:58
# 2    192.168.10.5              49188          6  03/07/2017 08:55:58
# 3    192.168.10.5              49188          6  03/07/2017 08:55:58
# 4   192.168.10.14              49486          6  03/07/2017 08:56:22
#
#     Flow Duration   Total Fwd Packets   Total Backward Packets  ...  \
# ...

# %%
df5 = pd.read_csv("TrafficLabelling/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv", encoding="iso-8859-1")

# %%
print(df5[" Label"].value_counts())
df5.head()
# Out:
# BENIGN          288566
# Infiltration        36
# Name:  Label, dtype: int64
#                                   Flow ID      Source IP   Source Port  \
# 0  192.168.10.12-192.168.10.50-60148-22-6  192.168.10.12         60148
# 1  192.168.10.12-192.168.10.50-60148-22-6  192.168.10.50            22
# 2  192.168.10.12-91.189.89.199-123-123-17  192.168.10.12           123
# 3  192.168.10.12-72.38.129.202-123-123-17  192.168.10.12           123
# 4                   8.0.6.4-8.6.0.1-0-0-0        8.6.0.1             0
#
#    Destination IP   Destination Port   Protocol      Timestamp  \
# 0   192.168.10.50                 22          6  6/7/2017 1:00
# 1   192.168.10.12              60148          6  6/7/2017 1:00
# 2   91.189.89.199                123         17  6/7/2017 1:00
# 3   72.38.129.202                123         17  6/7/2017 1:00
# 4         8.0.6.4                  0          0  6/7/2017 1:00
#
#     Flow Duration   Total Fwd Packets   Total Backward Packets  ...  \
# ...

# %%
df6 = pd.read_csv("TrafficLabelling/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv", encoding="iso-8859-1")

# %%
print(df6[" Label"].value_counts())
df6.head()
# Out:
# BENIGN                        168186
# Web Attack  Brute Force        1507
# Web Attack  XSS                 652
# Web Attack  Sql Injection        21
# Name:  Label, dtype: int64
#                                   Flow ID      Source IP   Source Port  \
# 0  192.168.10.3-192.168.10.50-389-33898-6  192.168.10.50       33898.0
# 1  192.168.10.3-192.168.10.50-389-33904-6  192.168.10.50       33904.0
# 2                   8.0.6.4-8.6.0.1-0-0-0        8.6.0.1           0.0
# 3  192.168.10.14-65.55.44.109-59135-443-6  192.168.10.14       59135.0
# 4  192.168.10.3-192.168.10.14-53-59555-17  192.168.10.14       59555.0
#
#    Destination IP   Destination Port   Protocol      Timestamp  \
# 0    192.168.10.3              389.0        6.0  6/7/2017 8:59
# 1    192.168.10.3              389.0        6.0  6/7/2017 8:59
# 2         8.0.6.4                0.0        0.0  6/7/2017 8:59
# 3    65.55.44.109              443.0        6.0  6/7/2017 8:59
# ...

# %%
df7 = pd.read_csv("TrafficLabelling/Tuesday-WorkingHours.pcap_ISCX.csv")

# %%
print(df7[" Label"].value_counts())
df7.head()
# Out:
# BENIGN         432074
# FTP-Patator      7938
# SSH-Patator      5897
# Name:  Label, dtype: int64
#                                 Flow ID     Source IP   Source Port  \
# 0  192.168.10.3-192.168.10.5-88-49182-6  192.168.10.5         49182
# 1  192.168.10.3-192.168.10.5-88-49183-6  192.168.10.5         49183
# 2  192.168.10.3-192.168.10.5-88-49184-6  192.168.10.5         49184
# 3  192.168.10.3-192.168.10.5-88-49185-6  192.168.10.5         49185
# 4  192.168.10.3-192.168.10.5-88-49186-6  192.168.10.5         49186
#
#    Destination IP   Destination Port   Protocol      Timestamp  \
# 0    192.168.10.3                 88          6  4/7/2017 8:54
# 1    192.168.10.3                 88          6  4/7/2017 8:54
# 2    192.168.10.3                 88          6  4/7/2017 8:54
# 3    192.168.10.3                 88          6  4/7/2017 8:54
# 4    192.168.10.3                 88          6  4/7/2017 8:54
#
#     Flow Duration   Total Fwd Packets   Total Backward Packets  ...  \
# ...

# %%
df8 = pd.read_csv("TrafficLabelling/Wednesday-workingHours.pcap_ISCX.csv")

# %%
print(df8[" Label"].value_counts())
df8.head()
# Out:
# BENIGN              440031
# DoS Hulk            231073
# DoS GoldenEye        10293
# DoS slowloris         5796
# DoS Slowhttptest      5499
# Heartbleed              11
# Name:  Label, dtype: int64
#                                   Flow ID      Source IP   Source Port  \
# 0  192.168.10.14-209.48.71.168-49459-80-6  192.168.10.14         49459
# 1  192.168.10.3-192.168.10.17-389-49453-6  192.168.10.17         49453
# 2   192.168.10.3-192.168.10.17-88-46124-6  192.168.10.17         46124
# 3  192.168.10.3-192.168.10.17-389-49454-6  192.168.10.17         49454
# 4   192.168.10.3-192.168.10.17-88-46126-6  192.168.10.17         46126
#
#    Destination IP   Destination Port   Protocol      Timestamp  \
# 0   209.48.71.168                 80          6  5/7/2017 8:42
# 1    192.168.10.3                389          6  5/7/2017 8:42
# 2    192.168.10.3                 88          6  5/7/2017 8:42
# 3    192.168.10.3                389          6  5/7/2017 8:42
# ...

# %%
df = pd.concat([df1,df2])
df = pd.concat([df,df3])
df = pd.concat([df,df4])
df = pd.concat([df,df5])
df = pd.concat([df,df6])
df = pd.concat([df,df7])
df = pd.concat([df,df8])

# %%
df = df.sample(frac=1)

# %%
df
# Out:
#                                          Flow ID      Source IP   Source Port  \
# 62162    192.168.10.50-207.210.46.249-123-123-17  192.168.10.50         123.0
# 526193  152.163.66.131-192.168.10.16-443-56372-6  192.168.10.16       56372.0
# 474587  192.168.10.17-23.194.141.180-44272-443-6  192.168.10.17       44272.0
# 390706    192.168.10.3-192.168.10.16-53-36457-17  192.168.10.16       36457.0
# 659824     192.168.10.3-192.168.10.5-53-58564-17   192.168.10.5       58564.0
# ...                                          ...            ...           ...
# 582729    192.168.10.3-192.168.10.19-53-35297-17  192.168.10.19       35297.0
# 278445     192.168.10.16-52.86.47.42-59644-443-6    52.86.47.42         443.0
# 291940     192.168.10.3-192.168.10.8-53-50859-17   192.168.10.8       50859.0
# 389840     192.168.10.8-23.21.212.138-54558-80-6   192.168.10.8       54558.0
# 141159       172.16.0.1-192.168.10.50-36990-80-6     172.16.0.1       36990.0
#
# ...

# %%
df[' Label'].value_counts()
# Out:
# BENIGN                        2273097
# DoS Hulk                       231073
# PortScan                       158930
# DDoS                           128027
# DoS GoldenEye                   10293
# FTP-Patator                      7938
# SSH-Patator                      5897
# DoS slowloris                    5796
# DoS Slowhttptest                 5499
# Bot                              1966
# Web Attack  Brute Force         1507
# Web Attack  XSS                  652
# Infiltration                       36
# Web Attack  Sql Injection         21
# Heartbleed                         11
# Name:  Label, dtype: int64

# %%
df.to_csv("CIC-IDS2017.csv", index=False)
